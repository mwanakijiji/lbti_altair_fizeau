# %%
# This makes a first contrast curve for Altair

# created 2018 Sept. 20 by E.S.

# %% [markdown]
# ## SECTION TO INITIALIZE

# %%
import urllib
import numpy as np
import matplotlib.pyplot as plt
import scipy
from scipy import ndimage

# %%
# import stuff

import PynPoint

from PynPoint import Pypeline
from PynPoint.IOmodules.Hdf5Reading import Hdf5ReadingModule
from PynPoint.IOmodules.FitsWriting import FitsWritingModule
from PynPoint.IOmodules.FitsReading import FitsReadingModule
from PynPoint.IOmodules.TextReading import ParangReadingModule, \
                                            AttributeReadingModule
from PynPoint.ProcessingModules import PSFpreparationModule, \
                                       PcaPsfSubtractionModule, \
                                       ContrastCurveModule, \
                                       FluxAndPosition, \
                                    StackingAndSubsampling
from PynPoint.ProcessingModules.StarAlignment import StarCenteringModule
#from PynPoint.ProcessingModules.StackingAndSubsampling import DerotateAndStackModule
from PynPoint.ProcessingModules.FluxAndPosition import FakePlanetModule
#from PynPoint.Util import AnalysisTools

# %%
import os
from astropy.io import fits
from astropy.modeling import models, fitting

# %%
# stem 

stem_base = ('/home/../../media/unasemaje/Elements/lbti_data_reduction/180507_fizeau_altair/')
stem_retrieve = (stem_base+'03_ramp_removed_pca_background_subted/')
stem_place = (stem_base+'04_gross_cookie_cutout/')
stem_place_centered = (stem_base+'05_centered/')
stem_place_fftinfo = (stem_base+'05b_fftinfo/')

# %% [markdown]
# # Make PSF cutouts

# %%
# Make cookie cut-outs of Fizeau PSFs (note the centering will not be great)
# retrieve from /03_ramp_removed_pca_background_subted/
# deposit in /04_gross_cookie_cutout/

# %%
def make_cutout(framenum):
    '''
    Write out cut-outs of PSFs
    '''
    
    img_string = 'lm_180507_'+str("{:0>6d}".format(framenum))+'_nPCA164.fits'
    
    # if file exists
    if os.path.isfile(stem_retrieve+img_string):
        
        # read in image
        sciImg, header = fits.getdata(stem_retrieve+img_string,0,header=True)
        
        if (framenum < 6303):
            psf_loc = [310,850] # (y,x) convention; for most frames <7735, where the PSF is in the up nod position
        elif ((framenum > 6302) and (framenum < 7735)):
            psf_loc = [343,807]
        elif ((framenum > 7772) and (framenum < 7927)):
            psf_loc = [153,824]            
        elif (framenum > 7926):
            psf_loc = [115,865] # (y,x) convention; for frames >7772, where the PSF is in the down nod position
        else:
            print("Frame number not legit!")
        
        # write a cookie-cut frame back out
        hdu = fits.PrimaryHDU(sciImg[psf_loc[0]-50:psf_loc[0]+50,
                                     psf_loc[1]-50:psf_loc[1]+50].astype(np.float64), 
                              header=header)
        hdul = fits.HDUList([hdu])
    
        hdul.writeto(stem_place+img_string, overwrite=True)
        #print('Saved '+str("{:0>6d}".format(framenum)))
        
    else:
        
        print('File '+img_string+' not found')

# %%
# make the cutouts

for frameNum in range(6303,7926):
    make_cutout(frameNum)
# Out:
# File lm_180507_006733_nPCA164.fits not found
# File lm_180507_006753_nPCA164.fits not found
# File lm_180507_006945_nPCA164.fits not found
# File lm_180507_006947_nPCA164.fits not found
# File lm_180507_007088_nPCA164.fits not found
# File lm_180507_007735_nPCA164.fits not found
# File lm_180507_007736_nPCA164.fits not found
# File lm_180507_007737_nPCA164.fits not found
# File lm_180507_007738_nPCA164.fits not found
# File lm_180507_007739_nPCA164.fits not found
# File lm_180507_007740_nPCA164.fits not found
# File lm_180507_007741_nPCA164.fits not found
# File lm_180507_007742_nPCA164.fits not found
# File lm_180507_007743_nPCA164.fits not found
# File lm_180507_007744_nPCA164.fits not found
# File lm_180507_007745_nPCA164.fits not found
# File lm_180507_007746_nPCA164.fits not found
# File lm_180507_007747_nPCA164.fits not found
# File lm_180507_007748_nPCA164.fits not found
# File lm_180507_007749_nPCA164.fits not found
# File lm_180507_007750_nPCA164.fits not found
# File lm_180507_007751_nPCA164.fits not found
# File lm_180507_007752_nPCA164.fits not found
# File lm_180507_007753_nPCA164.fits not found
# File lm_180507_007754_nPCA164.fits not found
# File lm_180507_007755_nPCA164.fits not found
# File lm_180507_007756_nPCA164.fits not found
# File lm_180507_007757_nPCA164.fits not found
# File lm_180507_007758_nPCA164.fits not found
# File lm_180507_007759_nPCA164.fits not found
# File lm_180507_007760_nPCA164.fits not found
# File lm_180507_007761_nPCA164.fits not found
# File lm_180507_007762_nPCA164.fits not found
# File lm_180507_007763_nPCA164.fits not found
# File lm_180507_007764_nPCA164.fits not found
# File lm_180507_007765_nPCA164.fits not found
# File lm_180507_007766_nPCA164.fits not found
# File lm_180507_007767_nPCA164.fits not found
# File lm_180507_007768_nPCA164.fits not found
# File lm_180507_007769_nPCA164.fits not found
# File lm_180507_007770_nPCA164.fits not found
# File lm_180507_007771_nPCA164.fits not found
# File lm_180507_007772_nPCA164.fits not found
# File lm_180507_007874_nPCA164.fits not found
# File lm_180507_007875_nPCA164.fits not found
# File lm_180507_007876_nPCA164.fits not found
# File lm_180507_007877_nPCA164.fits not found
# File lm_180507_007878_nPCA164.fits not found
# File lm_180507_007879_nPCA164.fits not found
# File lm_180507_007880_nPCA164.fits not found
# File lm_180507_007881_nPCA164.fits not found
# File lm_180507_007882_nPCA164.fits not found
# File lm_180507_007883_nPCA164.fits not found
# File lm_180507_007884_nPCA164.fits not found
# File lm_180507_007885_nPCA164.fits not found
# File lm_180507_007886_nPCA164.fits not found
# File lm_180507_007887_nPCA164.fits not found
# File lm_180507_007888_nPCA164.fits not found
# File lm_180507_007889_nPCA164.fits not found
# File lm_180507_007890_nPCA164.fits not found
# File lm_180507_007891_nPCA164.fits not found
# File lm_180507_007892_nPCA164.fits not found
# File lm_180507_007893_nPCA164.fits not found
# File lm_180507_007894_nPCA164.fits not found
# File lm_180507_007895_nPCA164.fits not found
# File lm_180507_007896_nPCA164.fits not found
# File lm_180507_007897_nPCA164.fits not found
# File lm_180507_007898_nPCA164.fits not found
# File lm_180507_007899_nPCA164.fits not found
# File lm_180507_007900_nPCA164.fits not found
# File lm_180507_007901_nPCA164.fits not found
# File lm_180507_007902_nPCA164.fits not found
# File lm_180507_007903_nPCA164.fits not found
# File lm_180507_007904_nPCA164.fits not found
# File lm_180507_007905_nPCA164.fits not found
# File lm_180507_007906_nPCA164.fits not found
# File lm_180507_007907_nPCA164.fits not found
# File lm_180507_007908_nPCA164.fits not found
# File lm_180507_007909_nPCA164.fits not found

# %% [markdown]
# # Define workspaces for PynPoint

# %%
# define workspaces and initialize Pypeline

working_place = stem_base+"./pynpoint_testing/pynpoint_experimentation_altair/working_place/jan12_working/"
input_place = stem_place
output_place = stem_base+"./pynpoint_testing/pynpoint_experimentation_altair/output_place/jan12_output/"

pipeline = Pypeline(working_place_in=working_place,
                    input_place_in=input_place,
                    output_place_in=output_place)

# now a *.ini file has been generated (this includes the PIXSCALE), if no pre-existing one was there
# Out:
# Initiating PynPoint... [DONE]

# %%
## IF THE *INI FILE WAS NEWLY GENERATED, EDIT THE *INI FILE TO SET
## PIXSCALE = 0.0107

# confirm PIXSCALE change
'''
pixscale_config = pipeline.get_attribute("config", "PIXSCALE")
print("Plate scale for /config/ is "+pixscale_config)
pixscale_sci = pipeline.get_attribute("science", "PIXSCALE")
print("Plate scale for /science/ is "+pixscale_sci)
'''
# Out:
# '\npixscale_config = pipeline.get_attribute("config", "PIXSCALE")\nprint("Plate scale for /config/ is "+pixscale_config)\npixscale_sci = pipeline.get_attribute("science", "PIXSCALE")\nprint("Plate scale for /science/ is "+pixscale_sci)\n'

# %% [markdown]
# ## READ IN DATA

# %%
# Read in all PSF cookie cut-outs from FITS files 

read_all_psfs = FitsReadingModule(name_in="read_all_psfs",
                                 input_dir=input_place,
                                 image_tag="all_psfs_precentering",
                                 check=True)

pipeline.add_module(read_all_psfs)

# %% [markdown]
# ## CENTER PSFS

# %%
center_psfs = StarCenteringModule(name_in="center_psfs", 
                                              image_in_tag="all_psfs_precentering", 
                                              image_out_tag="all_psfs_centered", 
                                              mask_out_tag=None, 
                                              fit_out_tag="center_fit", 
                                              method="full", 
                                              interpolation="spline", 
                                              radius=0.16, 
                                              sign="positive")

pipeline.add_module(center_psfs)


# write cube of centered frames (no PA correction)
write_centered_psfs = FitsWritingModule(file_name="centering_test.fits",
                              name_in="write_centered_psfs",
                              output_dir=output_place,
                              data_tag="all_psfs_centered")
                              
pipeline.add_module(write_centered_psfs)

# %%
pipeline.run()
# Out:
# Validating Pypeline... [DONE]
# Running FitsReadingModule... 0.1%
# /home/unasemaje/anaconda3/envs/py27/lib/python2.7/site-packages/PynPoint/IOmodules/FitsReading.py:167: UserWarning: Static attribute DIT (=ESO DET DIT) not found in the FITS header.
#   % (item, fitskey))
# /home/unasemaje/anaconda3/envs/py27/lib/python2.7/site-packages/PynPoint/IOmodules/FitsReading.py:167: UserWarning: Static attribute LONGITUDE (=ESO TEL GEOLON) not found in the FITS header.
#   % (item, fitskey))
# /home/unasemaje/anaconda3/envs/py27/lib/python2.7/site-packages/PynPoint/IOmodules/FitsReading.py:167: UserWarning: Static attribute LATITUDE (=ESO TEL GEOLAT) not found in the FITS header.
#   % (item, fitskey))
# /home/unasemaje/anaconda3/envs/py27/lib/python2.7/site-packages/PynPoint/IOmodules/FitsReading.py:197: UserWarning: Non-static attribute PUPIL (=ESO ADA PUPILPOS) not found in the FITS header.
#   "FITS header." % (item, fitskey))
# /home/unasemaje/anaconda3/envs/py27/lib/python2.7/site-packages/PynPoint/IOmodules/FitsReading.py:197: UserWarning: Non-static attribute DEC (=DEC) not found in the FITS header.
#   "FITS header." % (item, fitskey))
# /home/unasemaje/anaconda3/envs/py27/lib/python2.7/site-packages/PynPoint/IOmodules/FitsReading.py:197: UserWarning: Non-static attribute PARANG_END (=ESO ADA POSANG END) not found in the FITS header.
#   "FITS header." % (item, fitskey))
# /home/unasemaje/anaconda3/envs/py27/lib/python2.7/site-packages/PynPoint/IOmodules/FitsReading.py:197: UserWarning: Non-static attribute PARANG_START (=ESO ADA POSANG) not found in the FITS header.
#   "FITS header." % (item, fitskey))
# /home/unasemaje/anaconda3/envs/py27/lib/python2.7/site-packages/PynPoint/IOmodules/FitsReading.py:197: UserWarning: Non-static attribute DITHER_Y (=ESO SEQ CUMOFFSETY) not found in the FITS header.
#   "FITS header." % (item, fitskey))
# /home/unasemaje/anaconda3/envs/py27/lib/python2.7/site-packages/PynPoint/IOmodules/FitsReading.py:197: UserWarning: Non-static attribute RA (=RA) not found in the FITS header.
#   "FITS header." % (item, fitskey))
# /home/unasemaje/anaconda3/envs/py27/lib/python2.7/site-packages/PynPoint/IOmodules/FitsReading.py:197: UserWarning: Non-static attribute DITHER_X (=ESO SEQ CUMOFFSETX) not found in the FITS header.
#   "FITS header." % (item, fitskey))
# /home/unasemaje/anaconda3/envs/py27/lib/python2.7/site-packages/PynPoint/IOmodules/FitsReading.py:197: UserWarning: Non-static attribute EXP_NO (=ESO DET EXP NO) not found in the FITS header.
#   "FITS header." % (item, fitskey))
# /home/unasemaje/anaconda3/envs/py27/lib/python2.7/site-packages/PynPoint/IOmodules/FitsReading.py:197: UserWarning: Non-static attribute NDIT (=ESO DET NDIT) not found in the FITS header.
#   "FITS header." % (item, fitskey))
# Running FitsReadingModule... [DONE]
# Running StarCenteringModule... 0.0%
# /home/unasemaje/anaconda3/envs/py27/lib/python2.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# Running StarCenteringModule... [DONE]
# 2D Gaussian fit could not converge on 1016 image(s). [WARNING]
# Running FitsWritingModule... [DONE]

# %%
########################################################################################################################

# %% [markdown]
# # Now upsample and center the images again, without using PynPoint (requires Python 3.5 for plots)

# %%
#%matplotlib qt

# %%
# read in cutout frames

def center_cutouts(framenum):
    '''
    Center PSF cutouts without using PynPoint
    '''

    # fit 2D Gaussian
    img_string = 'lm_180507_'+str("{:0>6d}".format(framenum))+'_nPCA164.fits'
    
    # if file exists
    if os.path.isfile(stem_place+img_string):
        
        # read in image
        sciImg, header = fits.getdata(stem_place+img_string,0,header=True)
        
        # get coordinate grid info
        y, x = np.mgrid[0:np.shape(sciImg)[0],0:np.shape(sciImg)[1]]
        z = np.copy(sciImg)
        
        # make an initial Gaussian guess
        p_init = models.Gaussian2D(amplitude=60000.,
                                   x_mean=50.,
                                   y_mean=50.,
                                   x_stddev=6.,
                                   y_stddev=6.)
        fit_p = fitting.LevMarLSQFitter()

        # fit the data
        p = fit_p(p_init, x, y, z)
        ampl, x_mean, y_mean, x_stdev, y_stdev, theat = p._parameters
        
        # Plot the data with the best-fit model
        '''
        plt.clf()
        plt.figure(figsize=(8, 2.5))
        plt.subplot(1, 3, 1)
        plt.imshow(z, origin='lower', interpolation='nearest', vmin=-10, vmax=60000)
        plt.title("Data")
        plt.subplot(1, 3, 2)
        plt.imshow(p(x, y), origin='lower', interpolation='nearest', vmin=-10, vmax=60000)
        plt.title("Model")
        plt.subplot(1, 3, 3)
        plt.imshow(z - p(x, y), origin='lower', interpolation='nearest', vmin=-10, vmax=60000)
        plt.title("Residual")
        plt.suptitle("Frame "+str("{:0>6d}".format(framenum)))
        plt.savefig(stem_place_centered+'pngs_fits/png_fit_lm_180507_'+str("{:0>6d}".format(framenum))+'.png',overwrite=True)
        plt.close()
        '''
                
        # center the frame
        # N.b. for a 100x100 image, the physical center is at Python coordinate (49.5,49.5)
        # i.e., in between pixels 49 and 50 in both dimensions (Python convention),
        # or at coordinate (50.5,50.5) in DS9 convention
        sciImg_shifted = scipy.ndimage.interpolation.shift(sciImg, shift = [49.5-y_mean, 49.5-x_mean]) # shift in +y,+x convention
        
        # write a cookie-cut frame back out
        hdu = fits.PrimaryHDU(sciImg_shifted,header=header)
        hdul = fits.HDUList([hdu])
        hdul.writeto(stem_place_centered+'lm_180507_'+str("{:0>6d}".format(framenum))+'_nPCA164.fits', 
                     overwrite=True)
        
        print("Centered frame "+str("{:0>6d}".format(framenum)))

# %%
for frameNum in range(6303,7926):
    center_cutouts(frameNum)
# Out:
# Centered frame 006303
# Centered frame 006304
# Centered frame 006305
# Centered frame 006306
# Centered frame 006307
# Centered frame 006308
# Centered frame 006309
# Centered frame 006310
# Centered frame 006311
# Centered frame 006312
# Centered frame 006313
# Centered frame 006314
# Centered frame 006315
# Centered frame 006316
# Centered frame 006317
# Centered frame 006318
# Centered frame 006319
# Centered frame 006320
# Centered frame 006321
# Centered frame 006322
# Centered frame 006323
# Centered frame 006324
# Centered frame 006325
# Centered frame 006326
# Centered frame 006327
# Centered frame 006328
# Centered frame 006329
# Centered frame 006330
# Centered frame 006331
# Centered frame 006332
# Centered frame 006333
# Centered frame 006334
# Centered frame 006335
# Centered frame 006336
# Centered frame 006337
# Centered frame 006338
# Centered frame 006339
# Centered frame 006340
# Centered frame 006341
# Centered frame 006342
# Centered frame 006343
# Centered frame 006344
# Centered frame 006345
# Centered frame 006346
# Centered frame 006347
# Centered frame 006348
# Centered frame 006349
# Centered frame 006350
# Centered frame 006351
# Centered frame 006352
# Centered frame 006353
# Centered frame 006354
# Centered frame 006355
# Centered frame 006356
# Centered frame 006357
# Centered frame 006358
# Centered frame 006359
# Centered frame 006360
# Centered frame 006361
# Centered frame 006362
# Centered frame 006363
# Centered frame 006364
# Centered frame 006365
# Centered frame 006366
# Centered frame 006367
# Centered frame 006368
# Centered frame 006369
# Centered frame 006370
# Centered frame 006371
# Centered frame 006372
# Centered frame 006373
# Centered frame 006374
# Centered frame 006375
# Centered frame 006376
# Centered frame 006377
# Centered frame 006378
# Centered frame 006379
# Centered frame 006380
# Centered frame 006381
# Centered frame 006382
# Centered frame 006383
# Centered frame 006384
# Centered frame 006385
# Centered frame 006386
# Centered frame 006387
# Centered frame 006388
# Centered frame 006389
# Centered frame 006390
# Centered frame 006391
# Centered frame 006392
# Centered frame 006393
# Centered frame 006394
# Centered frame 006395
# Centered frame 006396
# Centered frame 006397
# Centered frame 006398
# Centered frame 006399
# Centered frame 006400
# Centered frame 006401
# Centered frame 006402
# Centered frame 006403
# Centered frame 006404
# Centered frame 006405
# Centered frame 006406
# Centered frame 006407
# Centered frame 006408
# Centered frame 006409
# Centered frame 006410
# Centered frame 006411
# Centered frame 006412
# Centered frame 006413
# Centered frame 006414
# Centered frame 006415
# Centered frame 006416
# Centered frame 006417
# Centered frame 006418
# Centered frame 006419
# Centered frame 006420
# Centered frame 006421
# Centered frame 006422
# Centered frame 006423
# Centered frame 006424
# Centered frame 006425
# Centered frame 006426
# Centered frame 006427
# Centered frame 006428
# Centered frame 006429
# Centered frame 006430
# Centered frame 006431
# Centered frame 006432
# Centered frame 006433
# Centered frame 006434
# Centered frame 006435
# Centered frame 006436
# Centered frame 006437
# Centered frame 006438
# Centered frame 006439
# Centered frame 006440
# Centered frame 006441
# Centered frame 006442
# Centered frame 006443
# Centered frame 006444
# Centered frame 006445
# Centered frame 006446
# Centered frame 006447
# Centered frame 006448
# Centered frame 006449
# Centered frame 006450
# Centered frame 006451
# Centered frame 006452
# Centered frame 006453
# Centered frame 006454
# Centered frame 006455
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Centered frame 006456
# Centered frame 006457
# Centered frame 006458
# Centered frame 006459
# Centered frame 006460
# Centered frame 006461
# Centered frame 006462
# Centered frame 006463
# Centered frame 006464
# Centered frame 006465
# Centered frame 006466
# Centered frame 006467
# Centered frame 006468
# Centered frame 006469
# Centered frame 006470
# Centered frame 006471
# Centered frame 006472
# Centered frame 006473
# Centered frame 006474
# Centered frame 006475
# Centered frame 006476
# Centered frame 006477
# Centered frame 006478
# Centered frame 006479
# Centered frame 006480
# Centered frame 006481
# Centered frame 006482
# Centered frame 006483
# Centered frame 006484
# Centered frame 006485
# Centered frame 006486
# Centered frame 006487
# Centered frame 006488
# Centered frame 006489
# Centered frame 006490
# Centered frame 006491
# Centered frame 006492
# Centered frame 006493
# Centered frame 006494
# Centered frame 006495
# Centered frame 006496
# Centered frame 006497
# Centered frame 006498
# Centered frame 006499
# Centered frame 006500
# Centered frame 006501
# Centered frame 006502
# Centered frame 006503
# Centered frame 006504
# Centered frame 006505
# Centered frame 006506
# Centered frame 006507
# Centered frame 006508
# Centered frame 006509
# Centered frame 006510
# Centered frame 006511
# Centered frame 006512
# Centered frame 006513
# Centered frame 006514
# Centered frame 006515
# Centered frame 006516
# Centered frame 006517
# Centered frame 006518
# Centered frame 006519
# Centered frame 006520
# Centered frame 006521
# Centered frame 006522
# Centered frame 006523
# Centered frame 006524
# Centered frame 006525
# Centered frame 006526
# Centered frame 006527
# Centered frame 006528
# Centered frame 006529
# Centered frame 006530
# Centered frame 006531
# Centered frame 006532
# Centered frame 006533
# Centered frame 006534
# Centered frame 006535
# Centered frame 006536
# Centered frame 006537
# Centered frame 006538
# Centered frame 006539
# Centered frame 006540
# Centered frame 006541
# Centered frame 006542
# Centered frame 006543
# Centered frame 006544
# Centered frame 006545
# Centered frame 006546
# Centered frame 006547
# Centered frame 006548
# Centered frame 006549
# Centered frame 006550
# Centered frame 006551
# Centered frame 006552
# Centered frame 006553
# Centered frame 006554
# Centered frame 006555
# Centered frame 006556
# Centered frame 006557
# Centered frame 006558
# Centered frame 006559
# Centered frame 006560
# Centered frame 006561
# Centered frame 006562
# Centered frame 006563
# Centered frame 006564
# Centered frame 006565
# Centered frame 006566
# Centered frame 006567
# Centered frame 006568
# Centered frame 006569
# Centered frame 006570
# Centered frame 006571
# Centered frame 006572
# Centered frame 006573
# Centered frame 006574
# Centered frame 006575
# Centered frame 006576
# Centered frame 006577
# Centered frame 006578
# Centered frame 006579
# Centered frame 006580
# Centered frame 006581
# Centered frame 006582
# Centered frame 006583
# Centered frame 006584
# Centered frame 006585
# Centered frame 006586
# Centered frame 006587
# Centered frame 006588
# Centered frame 006589
# Centered frame 006590
# Centered frame 006591
# Centered frame 006592
# Centered frame 006593
# Centered frame 006594
# Centered frame 006595
# Centered frame 006596
# Centered frame 006597
# Centered frame 006598
# Centered frame 006599
# Centered frame 006600
# Centered frame 006601
# Centered frame 006602
# Centered frame 006603
# Centered frame 006604
# Centered frame 006605
# Centered frame 006606
# Centered frame 006607
# Centered frame 006608
# Centered frame 006609
# Centered frame 006610
# Centered frame 006611
# Centered frame 006612
# Centered frame 006613
# Centered frame 006614
# Centered frame 006615
# Centered frame 006616
# Centered frame 006617
# Centered frame 006618
# Centered frame 006619
# Centered frame 006620
# Centered frame 006621
# Centered frame 006622
# Centered frame 006623
# Centered frame 006624
# Centered frame 006625
# Centered frame 006626
# Centered frame 006627
# Centered frame 006628
# Centered frame 006629
# Centered frame 006630
# Centered frame 006631
# Centered frame 006632
# Centered frame 006633
# Centered frame 006634
# Centered frame 006635
# Centered frame 006636
# Centered frame 006637
# Centered frame 006638
# Centered frame 006639
# Centered frame 006640
# Centered frame 006641
# Centered frame 006642
# Centered frame 006643
# Centered frame 006644
# Centered frame 006645
# Centered frame 006646
# Centered frame 006647
# Centered frame 006648
# Centered frame 006649
# Centered frame 006650
# Centered frame 006651
# Centered frame 006652
# Centered frame 006653
# Centered frame 006654
# Centered frame 006655
# Centered frame 006656
# Centered frame 006657
# Centered frame 006658
# Centered frame 006659
# Centered frame 006660
# Centered frame 006661
# Centered frame 006662
# Centered frame 006663
# Centered frame 006664
# Centered frame 006665
# Centered frame 006666
# Centered frame 006667
# Centered frame 006668
# Centered frame 006669
# Centered frame 006670
# Centered frame 006671
# Centered frame 006672
# Centered frame 006673
# Centered frame 006674
# Centered frame 006675
# Centered frame 006676
# Centered frame 006677
# Centered frame 006678
# Centered frame 006679
# Centered frame 006680
# Centered frame 006681
# Centered frame 006682
# Centered frame 006683
# Centered frame 006684
# Centered frame 006685
# Centered frame 006686
# Centered frame 006687
# Centered frame 006688
# Centered frame 006689
# Centered frame 006690
# Centered frame 006691
# Centered frame 006692
# Centered frame 006693
# Centered frame 006694
# Centered frame 006695
# Centered frame 006696
# Centered frame 006697
# Centered frame 006698
# Centered frame 006699
# Centered frame 006700
# Centered frame 006701
# Centered frame 006702
# Centered frame 006703
# Centered frame 006704
# Centered frame 006705
# Centered frame 006706
# Centered frame 006707
# Centered frame 006708
# Centered frame 006709
# Centered frame 006710
# Centered frame 006711
# Centered frame 006712
# Centered frame 006713
# Centered frame 006714
# Centered frame 006715
# Centered frame 006716
# Centered frame 006717
# Centered frame 006718
# Centered frame 006719
# Centered frame 006720
# Centered frame 006721
# Centered frame 006722
# Centered frame 006723
# Centered frame 006724
# Centered frame 006725
# Centered frame 006726
# Centered frame 006727
# Centered frame 006728
# Centered frame 006729
# Centered frame 006730
# Centered frame 006731
# Centered frame 006732
# Centered frame 006734
# Centered frame 006735
# Centered frame 006736
# Centered frame 006737
# Centered frame 006738
# Centered frame 006739
# Centered frame 006740
# Centered frame 006741
# Centered frame 006742
# Centered frame 006743
# Centered frame 006744
# Centered frame 006745
# Centered frame 006746
# Centered frame 006747
# Centered frame 006748
# Centered frame 006749
# Centered frame 006750
# Centered frame 006751
# Centered frame 006752
# Centered frame 006754
# Centered frame 006755
# Centered frame 006756
# Centered frame 006757
# Centered frame 006758
# Centered frame 006759
# Centered frame 006760
# Centered frame 006761
# Centered frame 006762
# Centered frame 006763
# Centered frame 006764
# Centered frame 006765
# Centered frame 006766
# Centered frame 006767
# Centered frame 006768
# Centered frame 006769
# Centered frame 006770
# Centered frame 006771
# Centered frame 006772
# Centered frame 006773
# Centered frame 006774
# Centered frame 006775
# Centered frame 006776
# Centered frame 006777
# Centered frame 006778
# Centered frame 006779
# Centered frame 006780
# Centered frame 006781
# Centered frame 006782
# Centered frame 006783
# Centered frame 006784
# Centered frame 006785
# Centered frame 006786
# Centered frame 006787
# Centered frame 006788
# Centered frame 006789
# Centered frame 006790
# Centered frame 006791
# Centered frame 006792
# Centered frame 006793
# Centered frame 006794
# Centered frame 006795
# Centered frame 006796
# Centered frame 006797
# Centered frame 006798
# Centered frame 006799
# Centered frame 006800
# Centered frame 006801
# Centered frame 006802
# Centered frame 006803
# Centered frame 006804
# Centered frame 006805
# Centered frame 006806
# Centered frame 006807
# Centered frame 006808
# Centered frame 006809
# Centered frame 006810
# Centered frame 006811
# Centered frame 006812
# Centered frame 006813
# Centered frame 006814
# Centered frame 006815
# Centered frame 006816
# Centered frame 006817
# Centered frame 006818
# Centered frame 006819
# Centered frame 006820
# Centered frame 006821
# Centered frame 006822
# Centered frame 006823
# Centered frame 006824
# Centered frame 006825
# Centered frame 006826
# Centered frame 006827
# Centered frame 006828
# Centered frame 006829
# Centered frame 006830
# Centered frame 006831
# Centered frame 006832
# Centered frame 006833
# Centered frame 006834
# Centered frame 006835
# Centered frame 006836
# Centered frame 006837
# Centered frame 006838
# Centered frame 006839
# Centered frame 006840
# Centered frame 006841
# Centered frame 006842
# Centered frame 006843
# Centered frame 006844
# Centered frame 006845
# Centered frame 006846
# Centered frame 006847
# Centered frame 006848
# Centered frame 006849
# Centered frame 006850
# Centered frame 006851
# Centered frame 006852
# Centered frame 006853
# Centered frame 006854
# Centered frame 006855
# Centered frame 006856
# Centered frame 006857
# Centered frame 006858
# Centered frame 006859
# Centered frame 006860
# Centered frame 006861
# Centered frame 006862
# Centered frame 006863
# Centered frame 006864
# Centered frame 006865
# Centered frame 006866
# Centered frame 006867
# Centered frame 006868
# Centered frame 006869
# Centered frame 006870
# Centered frame 006871
# Centered frame 006872
# Centered frame 006873
# Centered frame 006874
# Centered frame 006875
# Centered frame 006876
# Centered frame 006877
# Centered frame 006878
# Centered frame 006879
# Centered frame 006880
# Centered frame 006881
# Centered frame 006882
# Centered frame 006883
# Centered frame 006884
# Centered frame 006885
# Centered frame 006886
# Centered frame 006887
# Centered frame 006888
# Centered frame 006889
# Centered frame 006890
# Centered frame 006891
# Centered frame 006892
# Centered frame 006893
# Centered frame 006894
# Centered frame 006895
# Centered frame 006896
# Centered frame 006897
# Centered frame 006898
# Centered frame 006899
# Centered frame 006900
# Centered frame 006901
# Centered frame 006902
# Centered frame 006903
# Centered frame 006904
# Centered frame 006905
# Centered frame 006906
# Centered frame 006907
# Centered frame 006908
# Centered frame 006909
# Centered frame 006910
# Centered frame 006911
# Centered frame 006912
# Centered frame 006913
# Centered frame 006914
# Centered frame 006915
# Centered frame 006916
# Centered frame 006917
# Centered frame 006918
# Centered frame 006919
# Centered frame 006920
# Centered frame 006921
# Centered frame 006922
# Centered frame 006923
# Centered frame 006924
# Centered frame 006925
# Centered frame 006926
# Centered frame 006927
# Centered frame 006928
# Centered frame 006929
# Centered frame 006930
# Centered frame 006931
# Centered frame 006932
# Centered frame 006933
# Centered frame 006934
# Centered frame 006935
# Centered frame 006936
# Centered frame 006937
# Centered frame 006938
# Centered frame 006939
# Centered frame 006940
# Centered frame 006941
# Centered frame 006942
# Centered frame 006943
# Centered frame 006944
# Centered frame 006946
# Centered frame 006948
# Centered frame 006949
# Centered frame 006950
# Centered frame 006951
# Centered frame 006952
# Centered frame 006953
# Centered frame 006954
# Centered frame 006955
# Centered frame 006956
# Centered frame 006957
# Centered frame 006958
# Centered frame 006959
# Centered frame 006960
# Centered frame 006961
# Centered frame 006962
# Centered frame 006963
# Centered frame 006964
# Centered frame 006965
# Centered frame 006966
# Centered frame 006967
# Centered frame 006968
# Centered frame 006969
# Centered frame 006970
# Centered frame 006971
# Centered frame 006972
# Centered frame 006973
# Centered frame 006974
# Centered frame 006975
# Centered frame 006976
# Centered frame 006977
# Centered frame 006978
# Centered frame 006979
# Centered frame 006980
# Centered frame 006981
# Centered frame 006982
# Centered frame 006983
# Centered frame 006984
# Centered frame 006985
# Centered frame 006986
# Centered frame 006987
# Centered frame 006988
# Centered frame 006989
# Centered frame 006990
# Centered frame 006991
# Centered frame 006992
# Centered frame 006993
# Centered frame 006994
# Centered frame 006995
# Centered frame 006996
# Centered frame 006997
# Centered frame 006998
# Centered frame 006999
# Centered frame 007000
# Centered frame 007001
# Centered frame 007002
# Centered frame 007003
# Centered frame 007004
# Centered frame 007005
# Centered frame 007006
# Centered frame 007007
# Centered frame 007008
# Centered frame 007009
# Centered frame 007010
# Centered frame 007011
# Centered frame 007012
# Centered frame 007013
# Centered frame 007014
# Centered frame 007015
# Centered frame 007016
# Centered frame 007017
# Centered frame 007018
# Centered frame 007019
# Centered frame 007020
# Centered frame 007021
# Centered frame 007022
# Centered frame 007023
# Centered frame 007024
# Centered frame 007025
# Centered frame 007026
# Centered frame 007027
# Centered frame 007028
# Centered frame 007029
# Centered frame 007030
# Centered frame 007031
# Centered frame 007032
# Centered frame 007033
# Centered frame 007034
# Centered frame 007035
# Centered frame 007036
# Centered frame 007037
# Centered frame 007038
# Centered frame 007039
# Centered frame 007040
# Centered frame 007041
# Centered frame 007042
# Centered frame 007043
# Centered frame 007044
# Centered frame 007045
# Centered frame 007046
# Centered frame 007047
# Centered frame 007048
# Centered frame 007049
# Centered frame 007050
# Centered frame 007051
# Centered frame 007052
# Centered frame 007053
# Centered frame 007054
# Centered frame 007055
# Centered frame 007056
# Centered frame 007057
# Centered frame 007058
# Centered frame 007059
# Centered frame 007060
# Centered frame 007061
# Centered frame 007062
# Centered frame 007063
# Centered frame 007064
# Centered frame 007065
# Centered frame 007066
# Centered frame 007067
# Centered frame 007068
# Centered frame 007069
# Centered frame 007070
# Centered frame 007071
# Centered frame 007072
# Centered frame 007073
# Centered frame 007074
# Centered frame 007075
# Centered frame 007076
# Centered frame 007077
# Centered frame 007078
# Centered frame 007079
# Centered frame 007080
# Centered frame 007081
# Centered frame 007082
# Centered frame 007083
# Centered frame 007084
# Centered frame 007085
# Centered frame 007086
# Centered frame 007087
# Centered frame 007089
# Centered frame 007090
# Centered frame 007091
# Centered frame 007092
# Centered frame 007093
# Centered frame 007094
# Centered frame 007095
# Centered frame 007096
# Centered frame 007097
# Centered frame 007098
# Centered frame 007099
# Centered frame 007100
# Centered frame 007101
# Centered frame 007102
# Centered frame 007103
# Centered frame 007104
# Centered frame 007105
# Centered frame 007106
# Centered frame 007107
# Centered frame 007108
# Centered frame 007109
# Centered frame 007110
# Centered frame 007111
# Centered frame 007112
# Centered frame 007113
# Centered frame 007114
# Centered frame 007115
# Centered frame 007116
# Centered frame 007117
# Centered frame 007118
# Centered frame 007119
# Centered frame 007120
# Centered frame 007121
# Centered frame 007122
# Centered frame 007123
# Centered frame 007124
# Centered frame 007125
# Centered frame 007126
# Centered frame 007127
# Centered frame 007128
# Centered frame 007129
# Centered frame 007130
# Centered frame 007131
# Centered frame 007132
# Centered frame 007133
# Centered frame 007134
# Centered frame 007135
# Centered frame 007136
# Centered frame 007137
# Centered frame 007138
# Centered frame 007139
# Centered frame 007140
# Centered frame 007141
# Centered frame 007142
# Centered frame 007143
# Centered frame 007144
# Centered frame 007145
# Centered frame 007146
# Centered frame 007147
# Centered frame 007148
# Centered frame 007149
# Centered frame 007150
# Centered frame 007151
# Centered frame 007152
# Centered frame 007153
# Centered frame 007154
# Centered frame 007155
# Centered frame 007156
# Centered frame 007157
# Centered frame 007158
# Centered frame 007159
# Centered frame 007160
# Centered frame 007161
# Centered frame 007162
# Centered frame 007163
# Centered frame 007164
# Centered frame 007165
# Centered frame 007166
# Centered frame 007167
# Centered frame 007168
# Centered frame 007169
# Centered frame 007170
# Centered frame 007171
# Centered frame 007172
# Centered frame 007173
# Centered frame 007174
# Centered frame 007175
# Centered frame 007176
# Centered frame 007177
# Centered frame 007178
# Centered frame 007179
# Centered frame 007180
# Centered frame 007181
# Centered frame 007182
# Centered frame 007183
# Centered frame 007184
# Centered frame 007185
# Centered frame 007186
# Centered frame 007187
# Centered frame 007188
# Centered frame 007189
# Centered frame 007190
# Centered frame 007191
# Centered frame 007192
# Centered frame 007193
# Centered frame 007194
# Centered frame 007195
# Centered frame 007196
# Centered frame 007197
# Centered frame 007198
# Centered frame 007199
# Centered frame 007200
# Centered frame 007201
# Centered frame 007202
# Centered frame 007203
# Centered frame 007204
# Centered frame 007205
# Centered frame 007206
# Centered frame 007207
# Centered frame 007208
# Centered frame 007209
# Centered frame 007210
# Centered frame 007211
# Centered frame 007212
# Centered frame 007213
# Centered frame 007214
# Centered frame 007215
# Centered frame 007216
# Centered frame 007217
# Centered frame 007218
# Centered frame 007219
# Centered frame 007220
# Centered frame 007221
# Centered frame 007222
# Centered frame 007223
# Centered frame 007224
# Centered frame 007225
# Centered frame 007226
# Centered frame 007227
# Centered frame 007228
# Centered frame 007229
# Centered frame 007230
# Centered frame 007231
# Centered frame 007232
# Centered frame 007233
# Centered frame 007234
# Centered frame 007235
# Centered frame 007236
# Centered frame 007237
# Centered frame 007238
# Centered frame 007239
# Centered frame 007240
# Centered frame 007241
# Centered frame 007242
# Centered frame 007243
# Centered frame 007244
# Centered frame 007245
# Centered frame 007246
# Centered frame 007247
# Centered frame 007248
# Centered frame 007249
# Centered frame 007250
# Centered frame 007251
# Centered frame 007252
# Centered frame 007253
# Centered frame 007254
# Centered frame 007255
# Centered frame 007256
# Centered frame 007257
# Centered frame 007258
# Centered frame 007259
# Centered frame 007260
# Centered frame 007261
# Centered frame 007262
# Centered frame 007263
# Centered frame 007264
# Centered frame 007265
# Centered frame 007266
# Centered frame 007267
# Centered frame 007268
# Centered frame 007269
# Centered frame 007270
# Centered frame 007271
# Centered frame 007272
# Centered frame 007273
# Centered frame 007274
# Centered frame 007275
# Centered frame 007276
# Centered frame 007277
# Centered frame 007278
# Centered frame 007279
# Centered frame 007280
# Centered frame 007281
# Centered frame 007282
# Centered frame 007283
# Centered frame 007284
# Centered frame 007285
# Centered frame 007286
# Centered frame 007287
# Centered frame 007288
# Centered frame 007289
# Centered frame 007290
# Centered frame 007291
# Centered frame 007292
# Centered frame 007293
# Centered frame 007294
# Centered frame 007295
# Centered frame 007296
# Centered frame 007297
# Centered frame 007298
# Centered frame 007299
# Centered frame 007300
# Centered frame 007301
# Centered frame 007302
# Centered frame 007303
# Centered frame 007304
# Centered frame 007305
# Centered frame 007306
# Centered frame 007307
# Centered frame 007308
# Centered frame 007309
# Centered frame 007310
# Centered frame 007311
# Centered frame 007312
# Centered frame 007313
# Centered frame 007314
# Centered frame 007315
# Centered frame 007316
# Centered frame 007317
# Centered frame 007318
# Centered frame 007319
# Centered frame 007320
# Centered frame 007321
# Centered frame 007322
# Centered frame 007323
# Centered frame 007324
# Centered frame 007325
# Centered frame 007326
# Centered frame 007327
# Centered frame 007328
# Centered frame 007329
# Centered frame 007330
# Centered frame 007331
# Centered frame 007332
# Centered frame 007333
# Centered frame 007334
# Centered frame 007335
# Centered frame 007336
# Centered frame 007337
# Centered frame 007338
# Centered frame 007339
# Centered frame 007340
# Centered frame 007341
# Centered frame 007342
# Centered frame 007343
# Centered frame 007344
# Centered frame 007345
# Centered frame 007346
# Centered frame 007347
# Centered frame 007348
# Centered frame 007349
# Centered frame 007350
# Centered frame 007351
# Centered frame 007352
# Centered frame 007353
# Centered frame 007354
# Centered frame 007355
# Centered frame 007356
# Centered frame 007357
# Centered frame 007358
# Centered frame 007359
# Centered frame 007360
# Centered frame 007361
# Centered frame 007362
# Centered frame 007363
# Centered frame 007364
# Centered frame 007365
# Centered frame 007366
# Centered frame 007367
# Centered frame 007368
# Centered frame 007369
# Centered frame 007370
# Centered frame 007371
# Centered frame 007372
# Centered frame 007373
# Centered frame 007374
# Centered frame 007375
# Centered frame 007376
# Centered frame 007377
# Centered frame 007378
# Centered frame 007379
# Centered frame 007380
# Centered frame 007381
# Centered frame 007382
# Centered frame 007383
# Centered frame 007384
# Centered frame 007385
# Centered frame 007386
# Centered frame 007387
# Centered frame 007388
# Centered frame 007389
# Centered frame 007390
# Centered frame 007391
# Centered frame 007392
# Centered frame 007393
# Centered frame 007394
# Centered frame 007395
# Centered frame 007396
# Centered frame 007397
# Centered frame 007398
# Centered frame 007399
# Centered frame 007400
# Centered frame 007401
# Centered frame 007402
# Centered frame 007403
# Centered frame 007404
# Centered frame 007405
# Centered frame 007406
# Centered frame 007407
# Centered frame 007408
# Centered frame 007409
# Centered frame 007410
# Centered frame 007411
# Centered frame 007412
# Centered frame 007413
# Centered frame 007414
# Centered frame 007415
# Centered frame 007416
# Centered frame 007417
# Centered frame 007418
# Centered frame 007419
# Centered frame 007420
# Centered frame 007421
# Centered frame 007422
# Centered frame 007423
# Centered frame 007424
# Centered frame 007425
# Centered frame 007426
# Centered frame 007427
# Centered frame 007428
# Centered frame 007429
# Centered frame 007430
# Centered frame 007431
# Centered frame 007432
# Centered frame 007433
# Centered frame 007434
# Centered frame 007435
# Centered frame 007436
# Centered frame 007437
# Centered frame 007438
# Centered frame 007439
# Centered frame 007440
# Centered frame 007441
# Centered frame 007442
# Centered frame 007443
# Centered frame 007444
# Centered frame 007445
# Centered frame 007446
# Centered frame 007447
# Centered frame 007448
# Centered frame 007449
# Centered frame 007450
# Centered frame 007451
# Centered frame 007452
# Centered frame 007453
# Centered frame 007454
# Centered frame 007455
# Centered frame 007456
# Centered frame 007457
# Centered frame 007458
# Centered frame 007459
# Centered frame 007460
# Centered frame 007461
# Centered frame 007462
# Centered frame 007463
# Centered frame 007464
# Centered frame 007465
# Centered frame 007466
# Centered frame 007467
# Centered frame 007468
# Centered frame 007469
# Centered frame 007470
# Centered frame 007471
# Centered frame 007472
# Centered frame 007473
# Centered frame 007474
# Centered frame 007475
# Centered frame 007476
# Centered frame 007477
# Centered frame 007478
# Centered frame 007479
# Centered frame 007480
# Centered frame 007481
# Centered frame 007482
# Centered frame 007483
# Centered frame 007484
# Centered frame 007485
# Centered frame 007486
# Centered frame 007487
# Centered frame 007488
# Centered frame 007489
# Centered frame 007490
# Centered frame 007491
# Centered frame 007492
# Centered frame 007493
# Centered frame 007494
# Centered frame 007495
# Centered frame 007496
# Centered frame 007497
# Centered frame 007498
# Centered frame 007499
# Centered frame 007500
# Centered frame 007501
# Centered frame 007502
# Centered frame 007503
# Centered frame 007504
# Centered frame 007505
# Centered frame 007506
# Centered frame 007507
# Centered frame 007508
# Centered frame 007509
# Centered frame 007510
# Centered frame 007511
# Centered frame 007512
# Centered frame 007513
# Centered frame 007514
# Centered frame 007515
# Centered frame 007516
# Centered frame 007517
# Centered frame 007518
# Centered frame 007519
# Centered frame 007520
# Centered frame 007521
# Centered frame 007522
# Centered frame 007523
# Centered frame 007524
# Centered frame 007525
# Centered frame 007526
# Centered frame 007527
# Centered frame 007528
# Centered frame 007529
# Centered frame 007530
# Centered frame 007531
# Centered frame 007532
# Centered frame 007533
# Centered frame 007534
# Centered frame 007535
# Centered frame 007536
# Centered frame 007537
# Centered frame 007538
# Centered frame 007539
# Centered frame 007540
# Centered frame 007541
# Centered frame 007542
# Centered frame 007543
# Centered frame 007544
# Centered frame 007545
# Centered frame 007546
# Centered frame 007547
# Centered frame 007548
# Centered frame 007549
# Centered frame 007550
# Centered frame 007551
# Centered frame 007552
# Centered frame 007553
# Centered frame 007554
# Centered frame 007555
# Centered frame 007556
# Centered frame 007557
# Centered frame 007558
# Centered frame 007559
# Centered frame 007560
# Centered frame 007561
# Centered frame 007562
# Centered frame 007563
# Centered frame 007564
# Centered frame 007565
# Centered frame 007566
# Centered frame 007567
# Centered frame 007568
# Centered frame 007569
# Centered frame 007570
# Centered frame 007571
# Centered frame 007572
# Centered frame 007573
# Centered frame 007574
# Centered frame 007575
# Centered frame 007576
# Centered frame 007577
# Centered frame 007578
# Centered frame 007579
# Centered frame 007580
# Centered frame 007581
# Centered frame 007582
# Centered frame 007583
# Centered frame 007584
# Centered frame 007585
# Centered frame 007586
# Centered frame 007587
# Centered frame 007588
# Centered frame 007589
# Centered frame 007590
# Centered frame 007591
# Centered frame 007592
# Centered frame 007593
# Centered frame 007594
# Centered frame 007595
# Centered frame 007596
# Centered frame 007597
# Centered frame 007598
# Centered frame 007599
# Centered frame 007600
# Centered frame 007601
# Centered frame 007602
# Centered frame 007603
# Centered frame 007604
# Centered frame 007605
# Centered frame 007606
# Centered frame 007607
# Centered frame 007608
# Centered frame 007609
# Centered frame 007610
# Centered frame 007611
# Centered frame 007612
# Centered frame 007613
# Centered frame 007614
# Centered frame 007615
# Centered frame 007616
# Centered frame 007617
# Centered frame 007618
# Centered frame 007619
# Centered frame 007620
# Centered frame 007621
# Centered frame 007622
# Centered frame 007623
# Centered frame 007624
# Centered frame 007625
# Centered frame 007626
# Centered frame 007627
# Centered frame 007628
# Centered frame 007629
# Centered frame 007630
# Centered frame 007631
# Centered frame 007632
# Centered frame 007633
# Centered frame 007634
# Centered frame 007635
# Centered frame 007636
# Centered frame 007637
# Centered frame 007638
# Centered frame 007639
# Centered frame 007640
# Centered frame 007641
# Centered frame 007642
# Centered frame 007643
# Centered frame 007644
# Centered frame 007645
# Centered frame 007646
# Centered frame 007647
# Centered frame 007648
# Centered frame 007649
# Centered frame 007650
# Centered frame 007651
# Centered frame 007652
# Centered frame 007653
# Centered frame 007654
# Centered frame 007655
# Centered frame 007656
# Centered frame 007657
# Centered frame 007658
# Centered frame 007659
# Centered frame 007660
# Centered frame 007661
# Centered frame 007662
# Centered frame 007663
# Centered frame 007664
# Centered frame 007665
# Centered frame 007666
# Centered frame 007667
# Centered frame 007668
# Centered frame 007669
# Centered frame 007670
# Centered frame 007671
# Centered frame 007672
# Centered frame 007673
# Centered frame 007674
# Centered frame 007675
# Centered frame 007676
# Centered frame 007677
# Centered frame 007678
# Centered frame 007679
# Centered frame 007680
# Centered frame 007681
# Centered frame 007682
# Centered frame 007683
# Centered frame 007684
# Centered frame 007685
# Centered frame 007686
# Centered frame 007687
# Centered frame 007688
# Centered frame 007689
# Centered frame 007690
# Centered frame 007691
# Centered frame 007692
# Centered frame 007693
# Centered frame 007694
# Centered frame 007695
# Centered frame 007696
# Centered frame 007697
# Centered frame 007698
# Centered frame 007699
# Centered frame 007700
# Centered frame 007701
# Centered frame 007702
# Centered frame 007703
# Centered frame 007704
# Centered frame 007705
# Centered frame 007706
# Centered frame 007707
# Centered frame 007708
# Centered frame 007709
# Centered frame 007710
# Centered frame 007711
# Centered frame 007712
# Centered frame 007713
# Centered frame 007714
# Centered frame 007715
# Centered frame 007716
# Centered frame 007717
# Centered frame 007718
# Centered frame 007719
# Centered frame 007720
# Centered frame 007721
# Centered frame 007722
# Centered frame 007723
# Centered frame 007724
# Centered frame 007725
# Centered frame 007726
# Centered frame 007727
# Centered frame 007728
# Centered frame 007729
# Centered frame 007730
# Centered frame 007731
# Centered frame 007732
# Centered frame 007733
# Centered frame 007734
# Centered frame 007773
# Centered frame 007774
# Centered frame 007775
# Centered frame 007776
# Centered frame 007777
# Centered frame 007778
# Centered frame 007779
# Centered frame 007780
# Centered frame 007781
# Centered frame 007782
# Centered frame 007783
# Centered frame 007784
# Centered frame 007785
# Centered frame 007786
# Centered frame 007787
# Centered frame 007788
# Centered frame 007789
# Centered frame 007790
# Centered frame 007791
# Centered frame 007792
# Centered frame 007793
# Centered frame 007794
# Centered frame 007795
# Centered frame 007796
# Centered frame 007797
# Centered frame 007798
# Centered frame 007799
# Centered frame 007800
# Centered frame 007801
# Centered frame 007802
# Centered frame 007803
# Centered frame 007804
# Centered frame 007805
# Centered frame 007806
# Centered frame 007807
# Centered frame 007808
# Centered frame 007809
# Centered frame 007810
# Centered frame 007811
# Centered frame 007812
# Centered frame 007813
# Centered frame 007814
# Centered frame 007815
# Centered frame 007816
# Centered frame 007817
# Centered frame 007818
# Centered frame 007819
# Centered frame 007820
# Centered frame 007821
# Centered frame 007822
# Centered frame 007823
# Centered frame 007824
# Centered frame 007825
# Centered frame 007826
# Centered frame 007827
# Centered frame 007828
# Centered frame 007829
# Centered frame 007830
# Centered frame 007831
# Centered frame 007832
# Centered frame 007833
# Centered frame 007834
# Centered frame 007835
# Centered frame 007836
# Centered frame 007837
# Centered frame 007838
# Centered frame 007839
# Centered frame 007840
# Centered frame 007841
# Centered frame 007842
# Centered frame 007843
# Centered frame 007844
# Centered frame 007845
# Centered frame 007846
# Centered frame 007847
# Centered frame 007848
# Centered frame 007849
# Centered frame 007850
# Centered frame 007851
# Centered frame 007852
# Centered frame 007853
# Centered frame 007854
# Centered frame 007855
# Centered frame 007856
# Centered frame 007857
# Centered frame 007858
# Centered frame 007859
# Centered frame 007860
# Centered frame 007861
# Centered frame 007862
# Centered frame 007863
# Centered frame 007864
# Centered frame 007865
# Centered frame 007866
# Centered frame 007867
# Centered frame 007868
# Centered frame 007869
# Centered frame 007870
# Centered frame 007871
# Centered frame 007872
# Centered frame 007873
# Centered frame 007910
# Centered frame 007911
# Centered frame 007912
# Centered frame 007913
# Centered frame 007914
# Centered frame 007915
# Centered frame 007916
# Centered frame 007917
# Centered frame 007918
# Centered frame 007919
# Centered frame 007920
# Centered frame 007921
# Centered frame 007922
# Centered frame 007923
# Centered frame 007924
# Centered frame 007925

# %% [markdown]
# # Take FFTs of the newly centered images, and write characteristics to a file by using testing_making_set_masks_copiedFromFizControl.ipynb(has to run in Python 2.7!!)
