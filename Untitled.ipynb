# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import scipy
from astropy.io import fits
import pandas as pd
from datetime import datetime
# %matplotlib inline

# %%
sciImg9030, header = fits.getdata("lm_180507_009030.fits",0,header=True)
sciImg9940, header = fits.getdata("lm_180507_009940.fits",0,header=True)
sciImg5280, header = fits.getdata("lm_180507_005280.fits",0,header=True)
sciImg4752, header = fits.getdata("lm_180507_004752.fits",0,header=True)
sciImg9651, header = fits.getdata("lm_180507_009651.fits",0,header=True)
sciImg5494, header = fits.getdata("lm_180507_005494.fits",0,header=True)

# %%
plt.plot(np.max(sciImg9030,axis=0))
plt.plot(np.max(sciImg9940,axis=0))
plt.plot(np.max(sciImg5280,axis=0))
plt.plot(np.max(sciImg4752,axis=0))
plt.plot(np.max(sciImg9651,axis=0))
plt.plot(np.max(sciImg5494,axis=0))
#plt.ylim([50000,65000])
plt.axhline(y=55000)
plt.xlim([150,250])
plt.show()
